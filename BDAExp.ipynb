# %%
# !sudo apt-get install r-base
# !pip install rpy2
# %load_ext rpy2.ipython
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# r-base is already the newest version (4.4.1-3.2204.0).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
mkdir hadoop
cd hadoop/
vi hello.txt (i ,esc wq)
cat hello.txt


hdfs dfs -mkdir /today
hdfs dfs -put hello.txt /today/data.txt
hdfs dfs -cat /today/data.txt


hdfs dfs -mkdir /input (rmdir)
hdfs dfs -cp /today/data.txt /input/roneet.txt
hdfs dfs -cat /input/roneet.txt

hdfs dfs -get /input/roneet.txt
ls
# Out:
# ---------------------------------------------------------------------------
# RParsingError                             Traceback (most recent call last)
# <ipython-input-11-739e7999d987> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('R', '', 'mkdir hadoop\ncd hadoop/\nvi hello.txt (i ,esc wq)\ncat hello.txt\n\n\nhdfs dfs -mkdir /today\nhdfs dfs -put hello.txt /today/data.txt\nhdfs dfs -cat /today/data.txt\n\n\nhdfs dfs -mkdir /input (rmdir)\nhdfs dfs -cp /today/data.txt /input/roneet.txt\nhdfs dfs -cat /input/roneet.txt\n\nhdfs dfs -get /input/roneet.txt\nls\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
# ...

# %%
# !sudo apt-get install r-base
# !pip install rpy2
# %load_ext rpy2.ipython
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# r-base is already the newest version (4.4.1-3.2204.0).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...

# %%
# Run R code using %%R magic
# %%R
a <- 10
b <- 5

# Addition
sum_result <- a + b
cat("Sum:", sum_result, "\n")

# Subtraction
sub_result <- a - b
cat("Subtraction:", sub_result, "\n")

# Multiplication
mul_result <- a * b
cat("Multiplication:", mul_result, "\n")

# Division
div_result <- a / b
cat("Division:", div_result, "\n")

# Conditional
if (a > b) {
  cat("a is greater than b\n")
} else {
  cat("b is greater than or equal to a\n")
}
# Out:
# Sum: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2
# a is greater than b

# %%
# !sudo apt-get install r-base
# !pip install rpy2
# %load_ext rpy2.ipython
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# r-base is already the newest version (4.4.1-3.2204.0).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# # Generate 100 random numbers between 1 and 50
# random_numbers <- sample(1:50, 100, replace=TRUE)
#
# # Create a simple histogram
# hist(random_numbers,
#      main="Histogram of Random Numbers",
#      xlab="Random Numbers",
#      col="yellow",
#      border="black")

# %%
# %%R
# x <- 1:10
# y <- x^2
#
# plot(x,y, type = "l",col = "red", main= "Line Plot x vs x^2" , xlab = "x" , ylab = "x^2")

# %%
# %%R
# slices <- c(10,20,30,40)
# labels <- c("A","B","C","D")
#
# pie(slices,labels = labels, main = "PieChart", col = rainbow(length(slices)))

# %%
# %%R
# data_matrix <- matrix(rnorm(100) , nrow=10)
# heatmap(data_matrix, main = "HeatMap",col = heat.colors(256))

# %%
# %%R
# data<-(rnorm(100))
# boxplot(data, col = "light green", main = "Box Plot", border = "black", horizontal = TRUE )

# %%
# %%R
# x<-rnorm(100)
# y<-rnorm(100)
#
# plot(x,y, col = "green", main = "ScatterPlot", xlab = "x", ylab = "y" ,pch=19)
